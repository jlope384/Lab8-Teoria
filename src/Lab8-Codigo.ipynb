# %% [markdown]
# Ejercicio 1

# %%
import time
import matplotlib.pyplot as plt

def function1(n):
    counter = 0
    for i in range(n // 2, n + 1):
        for j in range(1, n - n // 2 + 1):
            k = 1
            while k <= n:
                counter += 1
                k *= 2
    return counter

#sizes_real = [1, 10, 100, 1000, 10000, 100000, 1000000]
sizes = [1, 10, 100, 1000, 10000]
times = []

for n in sizes:
    start = time.time()
    function1(n)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, tiempo={end - start:.6f} s")

plt.plot(sizes, times, marker='o')
plt.xlabel("Tamaño de                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   entrada (n)")
plt.ylabel("Tiempo de ejecución (s)")
plt.title("Ejercicio 1: Complejidad O(n^2 log n)")
plt.grid(True)
plt.show()
# Out:
# n=1, tiempo=0.000000 s
# n=10, tiempo=0.000000 s
# n=100, tiempo=0.001000 s
# n=1000, tiempo=0.093679 s
# n=10000, tiempo=13.810608 s

# %% [markdown]
# Ejercicio 2

# %%
import time
import matplotlib.pyplot as plt

def function2(n):
    if n <= 1:
        return
    for i in range(1, n + 1):
        for j in range(1, n + 1):
            _ = "Sequence"
            break

sizes = [1, 10, 100, 1000, 10000, 100000, 1000000]
times = []

for n in sizes:
    start = time.time()
    function2(n)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, tiempo={end - start:.6f} s")

plt.plot(sizes, times, marker='o', color='orange')
plt.xlabel("Tamaño de entrada (n)")
plt.ylabel("Tiempo de ejecución (s)")
plt.title("Ejercicio 2: Complejidad O(n)")
plt.grid(True)
plt.show()
# Out:
# n=1, tiempo=0.000000 s
# n=10, tiempo=0.000000 s
# n=100, tiempo=0.000000 s
# n=1000, tiempo=0.000000 s
# n=10000, tiempo=0.001006 s
# n=100000, tiempo=0.011379 s
# n=1000000, tiempo=0.105860 s

# %% [markdown]
# Ejercicio 3

# %%
import time
import matplotlib.pyplot as plt

def function3(n):
    for i in range(1, n // 3 + 1):
        for j in range(1, n + 1, 4):
            _ = "Sequence"

sizes = [1, 10, 100, 1000, 10000, 100000]
times = []

for n in sizes:
    start = time.time()
    function3(n)
    end = time.time()
    times.append(end - start)
    print(f"n={n}, tiempo={end - start:.6f} s")

plt.plot(sizes, times, marker='o', color='green')
plt.xlabel("Tamaño de entrada (n)")
plt.ylabel("Tiempo de ejecución (s)")
plt.title("Ejercicio 3: Complejidad O(n^2)")
plt.grid(True)
plt.show()
# Out:
# n=1, tiempo=0.000000 s
# n=10, tiempo=0.000000 s
# n=100, tiempo=0.000000 s
# n=1000, tiempo=0.001000 s
# n=10000, tiempo=0.145329 s
# n=100000, tiempo=14.683514 s
